# %% [markdown]
# # Módulo 10 tarefa 2
#
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
base = pd.read_csv('Profissão- Cientista de Dados_M10_support material.csv')
base
# Out:
#        Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0               0  2015-01-01   8682    F             False             True
# 1               1  2015-01-01  12830    M              True             True
# 2               2  2015-01-01   2885    M              True             True
# 3               3  2015-01-01  16168    F              True            False
# 4               4  2015-01-01  12438    M             False            False
# ...           ...         ...    ...  ...               ...              ...
# 14995       14995  2016-03-01   3678    M              True             True
# 14996       14996  2016-03-01   3405    M              True             True
# 14997       14997  2016-03-01   7944    F              True             True
# 14998       14998  2016-03-01  16019    F             False             True
# 14999       14999  2016-03-01  12895    F              True             True
#
# ...

# %% [markdown]
# 1) Com o que você viu em aula, faça uma análise das variáveis qualitativas (posse de imóvel e posse de veículo) para verificar se são boas preditoras de *renda*. Alguma delas parece discriminar *renda* de forma estatisticamente significante?

# %%
ax = sns.pointplot(x='posse_de_veiculo', y='renda', data=base, dodge=True, ci=95)

# %%
ax1 = sns.pointplot(x='posse_de_imovel', y='renda', data=base, dodge=True, ci=95)

# %% [markdown]
# # Ambas parecem deixar claro que aqueles indivíduos com maior renda tendem a ter imóveis e veículos, porém parece ser mais confiável se basear na análise da posse de veículo.
